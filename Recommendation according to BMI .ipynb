# %%
def calculate_bmi(weight, height):
    height=height/100
    bmi = weight / (height ** 2)
    return bmi

def bmi_category(bmi, age):
        if bmi < 18.5:
            return f"oooh {user} 😧! you are Underweight."
        
        elif 18.5 <= bmi < 24.9:
            return f"yahoo {user} 🥳🤞🏻! You are healthy."
        
        elif 25 <= bmi < 29.9:
            return f"Hmm {user} 😯! you are Overweight."
        
        else:
            return f"Oooh ho {user}😨!Obese."


title1 = "****🌻🙏🏻WELCOME TO SUNFLOWERS CODER'S BMI CALCULATOR🙏🏻🌻****"
title2 = "****PLEASE FILL THE BELOW DETAILS****"
width = 150
print(title1.center(width))
print(title2.center(width))

user=input("Enter your name:- ")

weight = int(input("Please Enter your Weight in kg :- "))
height = int(input("Please Enter your height in cm :- "))
age = int(input("Please Enter your age in number :- "))

bmi = calculate_bmi(weight, height)
category = bmi_category(bmi, age)


print(f"Your BMI is: {bmi}")
print(f"BMI category: {category}")

cen="----------------------------------------------------"
print(cen.center(width))

recommendation = input("Enter your BMI category here :- ")
if recommendation =="healthy":
    print(f"Food for Health:")
    print(f"Protein: Chicken, fish, tofu, beans, eggs.")
    print(f"Healthy Fats: Avocados, nuts, seeds, olive oil.")
    print(f"Carbs: Whole grains (quinoa, oats), sweet potatoes, legumes.")
    print(f"Fruits & Veggies: Leafy greens, berries, citrus, broccoli.")
    print(f"Hydration: Water, green tea, coconut water.")
    print(f"Snacks: Yogurt with nuts, fruit with almond butter.")
    
    print(f"Yoga:")
    print(f"Morning Flow: Sun Salutations, Downward Dog, Tree Pose..")
    print(f"Evening Relaxation: Child's Pose, Legs Up the Wall.")
    print(f"Breathing: Box Breathing, Nadi Shodhana (Alternate Nostril).")
    print(f"Mindfulness: Meditate for mental clarity.")

    print(f"Exercise:")
    print(f"Strength: Squats, lunges, push-ups (2-3 times/week).")
    print(f"Cardio: Running, cycling, HIIT (3-5 times/week).")
    print(f"Flexibility: Stretching or yoga post-exercise.")
    print(f"Active Recovery: Walking or light yoga.")

    
elif recommendation =="underweight":
    print(f"Food for underweight:")
    print(f"Protein: Chicken, eggs, Greek yogurt, lentils, tofu..")
    print(f"Healthy Fats: Avocados, nuts, seeds, olive oil, fatty fish.")
    print(f"Carbs: Whole grains (quinoa, oats), sweet potatoes.")
    print(f"Snacks: Protein smoothies, trail mix, nut butter.")
    print(f"Hydration: Water, green tea, coconut water.")
    print(f"Meal Frequency: Eat 5-6 smaller meals a day.")
    print(f"Calorie Surplus: Eat more than your daily calorie needs.")
    
    print(f"Yoga:")
    print(f"Strength Poses: Warrior Poses, Chair Pose, Plank Pose.")
    print(f"Recovery Poses: Child’s Pose, Forward Fold, Legs Up the Wall.")
    print(f"Breathing: Deep breathing, Ujjayi Pranayama.")
 

    print(f"Exercise:")
    print(f"Strength Training: Compound exercises (squats, push-ups, lunges, rows) 3-4 times/week.")
    print(f"Cardio: Moderate cardio (jogging, cycling) 2-3 times/week.")
    print(f"Flexibility: Stretching or yoga post-exercise.")
    print(f"Flexibility: Include yoga or stretches post-workout.")

elif recommendation =="overweight":
    print(f"Food for overweight:")
    print(f"Protein: Chicken, tofu, fish, eggs, legumes.")
    print(f"Healthy Fats: Avocados, nuts, seeds, olive oil.")
    print(f"Carbs: Whole grains, sweet potatoes, vegetables")
    print(f"Fruits & Veggies: Leafy greens, berries, broccoli.")
    print(f"Hydration: Water, herbal teas.")
    print(f"Calorie Deficit: Eat fewer calories than you burn..")
    print(f"Consistency: Stick to the routine for steady progress.")
    
    print(f"Yoga:")
    print(f"Strength Poses: Warrior Poses, Chair Pose, Plank Pose.")
    print(f"Relaxation Poses: Child’s Pose, Forward Fold, Legs Up the Wall.")
    print(f"Breathing: Deep breathing, Ujjayi Pranayama.")
 

    print(f"Exercise:")
    print(f"Cardio: Walking, cycling, swimming (30-45 minutes, 3-5 times/week).")
    print(f"Strength Training: Bodyweight exercises, dumbbells, resistance bands (2-3 times/week).")
    print(f"Flexibility: Dynamic stretches and yoga post-workout.")
 
else:
    print(f"Food for obese person:")
    print(f"Protein: Lean meats, tofu, fish, legumes")
    print(f"Healthy Fats: Avocados, nuts, seeds, olive oil")
    print(f"Carbs: Whole grains, sweet potatoes, veggies.")
    print(f"Fruits & Veggies: Leafy greens, berries, broccoli.")
    print(f"Hydration: Water, herbal teas.")
    print(f"Calorie Deficit: Eat fewer calories than you burn.")
    print(f"Consistency: Focus on long-term lifestyle changes")
    
    print(f"Yoga:")
    print(f"Strength Poses: Warrior I & II, Chair Pose, Plank Pose.")
    print(f"Relaxation Poses: Child’s Pose, Forward Fold, Legs Up the Wall.")
    print(f"Breathing: Deep breathing, Ujjayi Pranayama.")
 

    print(f"Exercise:")
    print(f"Cardio: Walking, cycling, swimming (30-45 minutes, 3-5 times/week)")
    print(f"Strength Training: Bodyweight exercises, resistance bands (2-3 times/week).")
    print(f"Flexibility: Dynamic stretches and yoga post-workout.")
